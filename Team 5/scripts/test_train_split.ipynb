# %%
# import modules
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
 
# read the dataset
df = pd.read_csv('Base.csv')
 
# get the locations
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
 
# split the dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.99, random_state=0)

# %%
X_train
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 23282            0     0.7               0.298873                         28
# 8281             0     0.4               0.566393                         -1
# 473964           0     0.8               0.372596                         -1
# 725960           0     0.8               0.135488                         -1
# 430872           0     0.9               0.199784                         -1
# ...            ...     ...                    ...                        ...
# 963395           0     0.7               0.615751                         -1
# 117952           0     0.4               0.789709                         -1
# 435829           0     0.7               0.405628                         -1
# 305711           0     0.4               0.591697                         -1
# 985772           0     0.9               0.067630                         -1
#
#         current_address_months_count  customer_age  days_since_request  \
# 23282                             48            30            0.001943
# 8281                              80            50            0.028554
# 473964                            31            30            0.024700
# 725960                           233            50            0.001453
# 430872                           133            40            0.011128
# ...                              ...           ...                 ...
# 963395                            43            40            0.004316
# 117952                            36            20            0.008571
# 435829                            13            50            0.003374
# 305711                            50            50            1.265285
# 985772                           159            40            0.020995
#
#         intended_balcon_amount payment_type  zip_count_4w  ...  \
# 23282                 8.945026           AA           962  ...
# 8281                 -1.053579           AB          4124  ...
# 473964               -0.797657           AC          2270  ...
# 725960               50.341675           AA          1556  ...
# 430872               27.942837           AA          2011  ...
# ...                        ...          ...           ...  ...
# 963395               49.874242           AA          2097  ...
# 117952               12.828529           AA          1762  ...
# 435829               -0.294296           AC          1301  ...
# 305711               35.793431           AA           672  ...
# 985772               -1.269600           AB           881  ...
#
#         bank_months_count  has_other_cards  proposed_credit_limit  \
# 23282                  10                0                  200.0
# 8281                   30                1                  200.0
# 473964                 -1                1                  500.0
# 725960                 31                0                  200.0
# 430872                  2                0                  200.0
# ...                   ...              ...                    ...
# 963395                 25                0                  200.0
# 117952                 15                0                 1500.0
# 435829                 -1                0                 2000.0
# 305711                  1                0                  200.0
# 985772                  1                1                  500.0
#
#         foreign_request    source session_length_in_minutes  device_os  \
# 23282                 0  INTERNET                  5.301326      other
# 8281                  0  INTERNET                  7.427500      linux
# 473964                0  INTERNET                  1.323140      linux
# 725960                0  INTERNET                 65.287446    windows
# 430872                0  INTERNET                  8.294146      other
# ...                 ...       ...                       ...        ...
# 963395                0  INTERNET                  1.813194      other
# 117952                0  INTERNET                  9.506439      other
# 435829                0  INTERNET                  5.243137      other
# 305711                0  INTERNET                  4.447468      other
# 985772                0  INTERNET                  3.629200      linux
#
#         keep_alive_session device_distinct_emails_8w  device_fraud_count
# 23282                    1                         1                   0
# 8281                     1                         1                   0
# 473964                   1                         1                   0
# 725960                   0                         2                   0
# 430872                   0                         1                   0
# ...                    ...                       ...                 ...
# 963395                   1                         1                   0
# 117952                   1                         1                   0
# 435829                   0                         1                   0
# 305711                   0                         1                   0
# 985772                   1                         1                   0
#
# [10000 rows x 31 columns]

# %%
X_test
# Out:
#         fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 157105           0     0.3               0.608648                         -1
# 374554           0     0.9               0.894561                         -1
# 688694           0     0.2               0.562969                         -1
# 265381           0     0.7               0.919602                         25
# 955415           1     0.4               0.496543                         -1
# ...            ...     ...                    ...                        ...
# 846893           0     0.1               0.662872                         35
# 107874           0     0.9               0.996108                         44
# 423387           0     0.9               0.013179                         -1
# 432814           0     0.9               0.853097                         -1
# 613347           0     0.8               0.391503                         -1
#
#         current_address_months_count  customer_age  days_since_request  \
# 157105                           316            50            0.039569
# 374554                           182            40            0.030706
# 688694                           192            40            0.008064
# 265381                           194            20            0.011597
# 955415                            31            30            0.007532
# ...                              ...           ...                 ...
# 846893                            11            30            0.021047
# 107874                             6            20            0.002973
# 423387                           155            70            0.001839
# 432814                           365            40            0.000577
# 613347                           102            30            0.000608
#
#         intended_balcon_amount payment_type  zip_count_4w  ...  \
# 157105              100.979826           AA           894  ...
# 374554               -0.953463           AB           670  ...
# 688694               -0.691529           AC           719  ...
# 265381               -0.905844           AB          1899  ...
# 955415               -1.075399           AB          4099  ...
# ...                        ...          ...           ...  ...
# 846893               49.169601           AA           744  ...
# 107874               -0.997576           AB          5128  ...
# 423387               -0.893440           AD          1131  ...
# 432814               -0.926608           AB          1559  ...
# 613347               -1.015690           AB          2430  ...
#
#         bank_months_count  has_other_cards  proposed_credit_limit  \
# 157105                 28                0                 1500.0
# 374554                 20                0                 1000.0
# 688694                 -1                0                 1000.0
# 265381                 31                1                  200.0
# 955415                  4                0                  200.0
# ...                   ...              ...                    ...
# 846893                  6                1                  200.0
# 107874                 -1                0                  200.0
# 423387                 30                0                  500.0
# 432814                 10                1                 1500.0
# 613347                 25                0                  200.0
#
#         foreign_request    source session_length_in_minutes  device_os  \
# 157105                0  INTERNET                 14.315332    windows
# 374554                0  INTERNET                  2.628434    windows
# 688694                0  INTERNET                  6.058244      other
# 265381                0  INTERNET                  2.779077    windows
# 955415                0  INTERNET                  1.190863    windows
# ...                 ...       ...                       ...        ...
# 846893                0  INTERNET                  2.132347        x11
# 107874                0  INTERNET                  8.129534      linux
# 423387                0  INTERNET                  5.831523    windows
# 432814                0  INTERNET                  3.542489      other
# 613347                0  INTERNET                  8.141617    windows
#
#         keep_alive_session device_distinct_emails_8w  device_fraud_count
# 157105                   1                         1                   0
# 374554                   0                         1                   0
# 688694                   1                         1                   0
# 265381                   0                         1                   0
# 955415                   0                         1                   0
# ...                    ...                       ...                 ...
# 846893                   0                         1                   0
# 107874                   1                         1                   0
# 423387                   0                         2                   0
# 432814                   1                         1                   0
# 613347                   0                         1                   0
#
# [990000 rows x 31 columns]

# %%
X_train.to_csv('train.csv')

# %%
X_test.to_csv('test.csv')

# %%
# read the dataset
df = pd.read_csv('train.csv')
 
# get the locations
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
 
# split the dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=0)

# %%
X_train
# Out:
#       Unnamed: 0  fraud_bool  income  name_email_similarity  \
# 333       752676           0     0.6               0.651119
# 6391      920486           0     0.7               0.994897
# 4786      632869           0     0.1               0.170645
# 357       744744           0     0.1               0.751258
# 9854      323714           0     0.1               0.120802
# ...          ...         ...     ...                    ...
# 9225      581596           0     0.8               0.241482
# 4859      562077           0     0.9               0.040741
# 3264      884126           0     0.8               0.046596
# 9845       14254           0     0.9               0.580919
# 2732       96497           0     0.9               0.163553
#
#       prev_address_months_count  current_address_months_count  customer_age  \
# 333                          -1                            85            40
# 6391                         -1                            43            30
# 4786                         -1                           119            50
# 357                          -1                           303            30
# 9854                         13                            20            30
# ...                         ...                           ...           ...
# 9225                         -1                           198            30
# 4859                          9                             6            50
# 3264                         -1                           258            70
# 9845                         -1                           304            10
# 2732                         -1                           161            20
#
#       days_since_request  intended_balcon_amount payment_type  ...  \
# 333             0.018277               -0.503640           AB  ...
# 6391            0.010421               -1.007437           AB  ...
# 4786           16.390627               -1.181701           AB  ...
# 357             1.297589               14.531360           AA  ...
# 9854            0.974729               35.486170           AA  ...
# ...                  ...                     ...          ...  ...
# 9225            0.014902               -1.538588           AD  ...
# 4859            0.000365               -0.811174           AD  ...
# 3264            0.035245               96.759550           AA  ...
# 9845            0.027637               -0.331198           AD  ...
# 2732            0.018050               -0.735198           AD  ...
#
#       phone_mobile_valid  bank_months_count  has_other_cards  \
# 333                    1                 31                1
# 6391                   0                 -1                1
# 4786                   1                 -1                1
# 357                    1                 26                0
# 9854                   1                 25                0
# ...                  ...                ...              ...
# 9225                   1                  1                1
# 4859                   0                  5                0
# 3264                   1                 15                1
# 9845                   1                  1                0
# 2732                   1                  1                0
#
#       proposed_credit_limit  foreign_request    source  \
# 333                   200.0                0  INTERNET
# 6391                  200.0                0  INTERNET
# 4786                  200.0                0  INTERNET
# 357                   200.0                0  INTERNET
# 9854                  200.0                0  INTERNET
# ...                     ...              ...       ...
# 9225                  200.0                0  INTERNET
# 4859                  200.0                1  INTERNET
# 3264                  500.0                0  INTERNET
# 9845                  200.0                0  INTERNET
# 2732                  200.0                0  INTERNET
#
#      session_length_in_minutes  device_os  keep_alive_session  \
# 333                  11.934006      other                   0
# 6391                  5.170110        x11                   0
# 4786                  5.921605      linux                   0
# 357                  16.300187      linux                   0
# 9854                 12.638366      other                   1
# ...                        ...        ...                 ...
# 9225                  5.388321      linux                   1
# 4859                  0.191044      linux                   1
# 3264                 10.590908    windows                   0
# 9845                  4.378752      other                   1
# 2732                  7.754051      other                   1
#
#      device_distinct_emails_8w
# 333                          1
# 6391                         1
# 4786                         1
# 357                          1
# 9854                         1
# ...                        ...
# 9225                         1
# 4859                         1
# 3264                         1
# 9845                         1
# 2732                         1
#
# [5000 rows x 31 columns]

# %%
X_test
# Out:
#       Unnamed: 0  fraud_bool  income  name_email_similarity  \
# 9394      580420           0     0.9               0.996666
# 898       234364           0     0.1               0.893003
# 2398      423679           0     0.3               0.349049
# 5906      440357           0     0.1               0.389945
# 2343       18402           0     0.7               0.926647
# ...          ...         ...     ...                    ...
# 3996       75925           0     0.8               0.475160
# 5889      508764           0     0.9               0.188521
# 4577      112564           0     0.3               0.188457
# 8600      426579           0     0.5               0.174661
# 847       777389           0     0.8               0.730981
#
#       prev_address_months_count  current_address_months_count  customer_age  \
# 9394                         26                            16            60
# 898                          10                            22            30
# 2398                         -1                           291            60
# 5906                         26                            40            20
# 2343                         44                             3            40
# ...                         ...                           ...           ...
# 3996                         50                            34            40
# 5889                         -1                            61            40
# 4577                         -1                            54            30
# 8600                         21                             0            40
# 847                          -1                           133            20
#
#       days_since_request  intended_balcon_amount payment_type  ...  \
# 9394            0.010543               -0.889544           AB  ...
# 898             0.009356               -1.388218           AB  ...
# 2398            0.007638               -1.113221           AB  ...
# 5906            0.006545               -1.051159           AC  ...
# 2343            0.016960               -1.097400           AC  ...
# ...                  ...                     ...          ...  ...
# 3996            0.020482               -0.534507           AD  ...
# 5889            0.725156               -0.825708           AC  ...
# 4577            0.016062               -1.218699           AB  ...
# 8600            0.004039               -0.490101           AC  ...
# 847             0.001381               -0.831595           AC  ...
#
#       phone_mobile_valid  bank_months_count  has_other_cards  \
# 9394                   1                 28                0
# 898                    0                  1                1
# 2398                   1                 15                0
# 5906                   1                 -1                0
# 2343                   1                  1                0
# ...                  ...                ...              ...
# 3996                   1                  2                0
# 5889                   1                 -1                0
# 4577                   1                  1                0
# 8600                   1                 -1                0
# 847                    0                 25                0
#
#       proposed_credit_limit  foreign_request    source  \
# 9394                  200.0                0  INTERNET
# 898                   200.0                0  INTERNET
# 2398                 1000.0                0  INTERNET
# 5906                  200.0                0  INTERNET
# 2343                  500.0                0  INTERNET
# ...                     ...              ...       ...
# 3996                  200.0                0  INTERNET
# 5889                  200.0                0  INTERNET
# 4577                  200.0                0  INTERNET
# 8600                  200.0                0  INTERNET
# 847                   200.0                0  INTERNET
#
#      session_length_in_minutes  device_os  keep_alive_session  \
# 9394                  9.889169    windows                   0
# 898                  20.529742      linux                   1
# 2398                  3.764299        x11                   1
# 5906                  9.111233      linux                   0
# 2343                  3.624892      linux                   1
# ...                        ...        ...                 ...
# 3996                  6.143168      linux                   1
# 5889                  5.825198      other                   1
# 4577                  2.867567      linux                   1
# 8600                  8.075096  macintosh                   0
# 847                   1.576238      other                   0
#
#      device_distinct_emails_8w
# 9394                         1
# 898                          1
# 2398                         1
# 5906                         2
# 2343                         1
# ...                        ...
# 3996                         1
# 5889                         1
# 4577                         1
# 8600                         1
# 847                          1
#
# [5000 rows x 31 columns]

# %%
# read the dataset
df = pd.read_csv('train.csv')
 
# get the locations
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
 
# split the dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.15, random_state=0)

# %%
X_train
# Out:
#       Unnamed: 0  fraud_bool  income  name_email_similarity  \
# 7800      623254           0     0.7               0.247842
# 9453      293001           0     0.1               0.108117
# 9690      736108           0     0.1               0.622975
# 6477      194466           0     0.1               0.337774
# 4178      834668           0     0.1               0.509048
# ...          ...         ...     ...                    ...
# 9225      581596           0     0.8               0.241482
# 4859      562077           0     0.9               0.040741
# 3264      884126           0     0.8               0.046596
# 9845       14254           0     0.9               0.580919
# 2732       96497           0     0.9               0.163553
#
#       prev_address_months_count  current_address_months_count  customer_age  \
# 7800                         -1                            42            20
# 9453                         -1                            48            50
# 9690                         -1                            64            30
# 6477                         -1                           147            20
# 4178                         -1                           126            30
# ...                         ...                           ...           ...
# 9225                         -1                           198            30
# 4859                          9                             6            50
# 3264                         -1                           258            70
# 9845                         -1                           304            10
# 2732                         -1                           161            20
#
#       days_since_request  intended_balcon_amount payment_type  ...  \
# 7800            0.018297               28.687771           AA  ...
# 9453            0.018604               -0.949068           AB  ...
# 9690            0.012990               -1.113924           AD  ...
# 6477            0.012255               -0.952556           AA  ...
# 4178            0.017890               -0.848851           AB  ...
# ...                  ...                     ...          ...  ...
# 9225            0.014902               -1.538588           AD  ...
# 4859            0.000365               -0.811174           AD  ...
# 3264            0.035245               96.759550           AA  ...
# 9845            0.027637               -0.331198           AD  ...
# 2732            0.018050               -0.735198           AD  ...
#
#       phone_mobile_valid  bank_months_count  has_other_cards  \
# 7800                   1                 10                0
# 9453                   1                 21                0
# 9690                   1                 -1                0
# 6477                   1                 20                0
# 4178                   1                 10                1
# ...                  ...                ...              ...
# 9225                   1                  1                1
# 4859                   0                  5                0
# 3264                   1                 15                1
# 9845                   1                  1                0
# 2732                   1                  1                0
#
#       proposed_credit_limit  foreign_request    source  \
# 7800                 1500.0                0  INTERNET
# 9453                  200.0                0  INTERNET
# 9690                 1500.0                0  INTERNET
# 6477                  500.0                0  INTERNET
# 4178                  200.0                0  INTERNET
# ...                     ...              ...       ...
# 9225                  200.0                0  INTERNET
# 4859                  200.0                1  INTERNET
# 3264                  500.0                0  INTERNET
# 9845                  200.0                0  INTERNET
# 2732                  200.0                0  INTERNET
#
#      session_length_in_minutes  device_os  keep_alive_session  \
# 7800                  3.980733  macintosh                   0
# 9453                 14.314625      other                   1
# 9690                  3.009260      other                   0
# 6477                  2.883457    windows                   1
# 4178                  5.567120      linux                   0
# ...                        ...        ...                 ...
# 9225                  5.388321      linux                   1
# 4859                  0.191044      linux                   1
# 3264                 10.590908    windows                   0
# 9845                  4.378752      other                   1
# 2732                  7.754051      other                   1
#
#      device_distinct_emails_8w
# 7800                         1
# 9453                         1
# 9690                         1
# 6477                         1
# 4178                         1
# ...                        ...
# 9225                         1
# 4859                         1
# 3264                         1
# 9845                         1
# 2732                         1
#
# [8500 rows x 31 columns]

# %%
X_test
# Out:
#       Unnamed: 0  fraud_bool  income  name_email_similarity  \
# 9394      580420           0     0.9               0.996666
# 898       234364           0     0.1               0.893003
# 2398      423679           0     0.3               0.349049
# 5906      440357           0     0.1               0.389945
# 2343       18402           0     0.7               0.926647
# ...          ...         ...     ...                    ...
# 7990      747571           0     0.8               0.175727
# 5056      454051           0     0.1               0.858874
# 3910      571325           0     0.1               0.444382
# 1281      266920           0     0.1               0.996726
# 8022      815858           0     0.8               0.880127
#
#       prev_address_months_count  current_address_months_count  customer_age  \
# 9394                         26                            16            60
# 898                          10                            22            30
# 2398                         -1                           291            60
# 5906                         26                            40            20
# 2343                         44                             3            40
# ...                         ...                           ...           ...
# 7990                         -1                            48            40
# 5056                         -1                            14            30
# 3910                         30                             8            20
# 1281                         -1                            36            20
# 8022                         -1                            75            50
#
#       days_since_request  intended_balcon_amount payment_type  ...  \
# 9394            0.010543               -0.889544           AB  ...
# 898             0.009356               -1.388218           AB  ...
# 2398            0.007638               -1.113221           AB  ...
# 5906            0.006545               -1.051159           AC  ...
# 2343            0.016960               -1.097400           AC  ...
# ...                  ...                     ...          ...  ...
# 7990            0.025746               -1.627785           AB  ...
# 5056            0.010397               38.715796           AA  ...
# 3910            0.003927               -0.838569           AB  ...
# 1281            0.018230               -1.183379           AB  ...
# 8022            0.005188              103.475771           AA  ...
#
#       phone_mobile_valid  bank_months_count  has_other_cards  \
# 9394                   1                 28                0
# 898                    0                  1                1
# 2398                   1                 15                0
# 5906                   1                 -1                0
# 2343                   1                  1                0
# ...                  ...                ...              ...
# 7990                   1                 25                0
# 5056                   1                 26                0
# 3910                   1                 28                1
# 1281                   1                  1                0
# 8022                   1                 25                0
#
#       proposed_credit_limit  foreign_request    source  \
# 9394                  200.0                0  INTERNET
# 898                   200.0                0  INTERNET
# 2398                 1000.0                0  INTERNET
# 5906                  200.0                0  INTERNET
# 2343                  500.0                0  INTERNET
# ...                     ...              ...       ...
# 7990                  200.0                0  INTERNET
# 5056                 1000.0                0  INTERNET
# 3910                 1000.0                0  INTERNET
# 1281                  200.0                0  INTERNET
# 8022                  200.0                0  INTERNET
#
#      session_length_in_minutes  device_os  keep_alive_session  \
# 9394                  9.889169    windows                   0
# 898                  20.529742      linux                   1
# 2398                  3.764299        x11                   1
# 5906                  9.111233      linux                   0
# 2343                  3.624892      linux                   1
# ...                        ...        ...                 ...
# 7990                  1.760698      linux                   1
# 5056                  6.451808      other                   1
# 3910                  1.332327      linux                   1
# 1281                  7.627868      other                   1
# 8022                  5.258928      linux                   0
#
#      device_distinct_emails_8w
# 9394                         1
# 898                          1
# 2398                         1
# 5906                         2
# 2343                         1
# ...                        ...
# 7990                         1
# 5056                         1
# 3910                         1
# 1281                         1
# 8022                         1
#
# [1500 rows x 31 columns]
